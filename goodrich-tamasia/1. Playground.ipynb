# %% [markdown]
# ### 0. `a+b` test

# %%
line = input("Enter two integers separated by space: ")
a, b = map(int, line.split())
print(a + b)
# Out:
# 7

# %%
# always end sessions with Resume Context: Write enough context to resume tomorrow without starting to understand from scratch
